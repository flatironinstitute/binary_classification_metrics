# %% [markdown]
# # Thoughts on evaluating binary classifiers (etcetera).
#
# ## This presentation discusses methodologies and metrics for evaluating classifiers.
#
# ## I'm not an expert but I've thought about it a fair amount over the last 5 years.
#
# ## Many thanks for discussions with Charlie Strauss last week.
#
# ## Less recently: thanks to Emily Miraldi, Dayanne Castro and others...
#
# # Along the way we demonstrate how to use Jupyter widgets for interactive data exploration.

# %% [markdown]
# <h2>
#     <a href="./1_recent_work.ipynb">
#     What have I been doing recently?
#     </a>
# </h2>
#
# <h2>
#     <a href="./2_Bio_work.ipynb">
#     ... Relevant to systems biology?
#     </a>
# </h2>
#
# <h2>
#     <a href="./3_Concerning_Jupyter_widgets.ipynb">
#     Concerning Jupyter Widgets
#     </a>
# </h2>
#
# <h2>
#     <a href="./4_Binary_classification_definition.ipynb">
#     What is a binary classification ranking?
#     </a>
# </h2>
#
# <h2>
#     <a href="./5_Web_search.ipynb">
#     Use case: Web search ranking.
#     </a>
# </h2>
#
# <h2>
#     <a href="./6_Radar.ipynb">
#     Use case: Anti-aircraft radar.
#     </a>
# </h2>
#
# <h2>
#     <a href="./7_Ambiguity.ipynb">
#     Ambiguity and stability: What if you don't know what a cat looks like?
#     </a>
# </h2>
#
# <h2>
#     <a href="./8_carcinogens.ipynb">
#     Use case: Eliminating carcinogens.
#     </a>
# </h2>
#
# <h2>
#     <a href="./9_antiviral.ipynb">
#     Use case: Looking for an antiviral drug.
#     </a>
# </h2>
#
# <h2>
#     <a href="./10_ranking_rankings.ipynb">
#     Ranking rankings: overview.
#     </a>
# </h2>
#
# <h2>
#     <a href="./11_cats_or_bombers.ipynb">
#     Cats or bombers: AUPR versus AUROC.
#     </a>
# </h2>
#
# <h2>
#     <a href="./12_stability.ipynb">
#     Lions versus anteaters: What if your gold standard has errors or "unknowns"?
#     </a>
# </h2>
#
# <h2>
#     <a href="./13_other_metrics.ipynb">
#     Other metrics for ranking rankings.
#     </a>
# </h2>
#
# <h2>
#     <a href="./14_Conclusion.ipynb">
#     Conclusion.
#     </a>
# </h2>
